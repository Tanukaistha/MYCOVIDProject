# %%
import pandas as pd
from pandas import DataFrame as df
from matplotlib import style, pyplot as plot
from datetime import datetime

df = pd.read_csv('covid_19_india.csv', index_col=1, parse_dates=True, dayfirst=True)

start_date = '2020-06-01'
end_date   = '2020-06-30'

df = df.loc[start_date : end_date]

dFrame = df.loc[(df['State/UnionTerritory'] == 'Delhi')]

df = pd.DataFrame(dFrame)

df = df.reset_index()

df.get(['Sno', 'Date', 'State/UnionTerritory', 'Cured', 'Deaths', 'Confirmed'])

for ind in df.index: 
    #Extract data row by row
    df['Date'][ind], df['State/UnionTerritory'][ind], df['Cured'][ind], df['Deaths'][ind], df['Confirmed'][ind]
df
# Out:
#          Date   Sno     Time State/UnionTerritory ConfirmedIndianNational  \
# 0  2020-06-01  2531  8:00 AM                Delhi                       -
# 1  2020-06-02  2567  8:00 AM                Delhi                       -
# 2  2020-06-03  2603  8:00 AM                Delhi                       -
# 3  2020-06-04  2639  8:00 AM                Delhi                       -
# 4  2020-06-05  2675  8:00 AM                Delhi                       -
# 5  2020-06-06  2711  8:00 AM                Delhi                       -
# 6  2020-06-07  2747  8:00 AM                Delhi                       -
# 7  2020-06-08  2783  8:00 AM                Delhi                       -
# 8  2020-06-09  2819  8:00 AM                Delhi                       -
# 9  2020-06-10  2855  8:00 AM                Delhi                       -
# 10 2020-06-11  2892  8:00 AM                Delhi                       -
# 11 2020-06-12  2928  8:00 AM                Delhi                       -
# 12 2020-06-13  2964  8:00 AM                Delhi                       -
# 13 2020-06-14  3000  8:00 AM                Delhi                       -
# 14 2020-06-15  3036  8:00 AM                Delhi                       -
# 15 2020-06-16  3072  8:00 AM                Delhi                       -
# 16 2020-06-17  3108  8:00 AM                Delhi                       -
# 17 2020-06-18  3144  8:00 AM                Delhi                       -
# 18 2020-06-19  3180  8:00 AM                Delhi                       -
# 19 2020-06-20  3216  8:00 AM                Delhi                       -
# 20 2020-06-21  3252  8:00 AM                Delhi                       -
# 21 2020-06-22  3288  8:00 AM                Delhi                       -
# 22 2020-06-23  3324  8:00 AM                Delhi                       -
# 23 2020-06-24  3360  8:00 AM                Delhi                       -
# 24 2020-06-25  3396  8:00 AM                Delhi                       -
# 25 2020-06-26  3432  8:00 AM                Delhi                       -
# 26 2020-06-27  3468  8:00 AM                Delhi                       -
# 27 2020-06-28  3504  8:00 AM                Delhi                       -
# 28 2020-06-29  3540  8:00 AM                Delhi                       -
# 29 2020-06-30  3576  8:00 AM                Delhi                       -
#
#    ConfirmedForeignNational  Cured  Deaths  Confirmed
# 0                         -   8478     473      19844
# 1                         -   8746     523      20834
# 2                         -   9243     556      22132
# 3                         -   9542     606      23645
# 4                         -   9898     650      25004
# 5                         -  10315     708      26334
# 6                         -  10664     761      27654
# 7                         -  10664     761      27654
# 8                         -  11357     874      29943
# 9                         -  11861     905      31309
# 10                        -  12245     984      32810
# 11                        -  12731    1085      34687
# 12                        -  13398    1214      36824
# 13                        -  14945    1271      38958
# 14                        -  15823    1327      41182
# 15                        -  16427    1400      42829
# 16                        -  16500    1837      44688
# 17                        -  17457    1904      47102
# 18                        -  21341    1969      49979
# 19                        -  23569    2035      53116
# 20                        -  31294    2112      56746
# 21                        -  33013    2175      59746
# 22                        -  36602    2233      62655
# 23                        -  39313    2301      66602
# 24                        -  41437    2365      70390
# 25                        -  44765    2429      73780
# 26                        -  47091    2492      77240
# 27                        -  49301    2558      80188
# 28                        -  52607    2623      83077
# 29                        -  56235    2680      85161

# %%
dateList = [i.strftime("%d") for i in df['Date'].tolist()]


plot.plot(dateList,df['Confirmed'].tolist(),'g', label='Confirmed In Delhi', linewidth =1)
plot.plot(dateList,df['Cured'].tolist(),'b', label='Cured In Delhi', linewidth =1)
plot.plot(dateList,df['Deaths'].tolist(),'r', label='Deaths In Delhi', linewidth =1)

plot.title('COVID-19 DATA ')
plot.xlabel('Days Of June')
plot.xticks(rotation=90)
plot.ylabel('Number Of People')
plot.legend()

plot.grid(True, color='K')
plot.legend(loc='best')
plot.savefig('Delhi1.jpg')
plot.show()

# %%
df = pd.read_csv('covid_19_india.csv', index_col=1, parse_dates=True, dayfirst=True)

start_date = '2020-06-01'
end_date   = '2020-06-30'

df = df.loc[start_date : end_date]

dFrame = df.loc[(df['State/UnionTerritory'] == 'Haryana')]

df = pd.DataFrame(dFrame)

df = df.reset_index()

df.get(['Sno', 'Date', 'State/UnionTerritory', 'Cured', 'Deaths', 'Confirmed'])

for ind in df.index: 
    #Extract data row by row
    df['Date'][ind], df['State/UnionTerritory'][ind], df['Cured'][ind], df['Deaths'][ind], df['Confirmed'][ind]
df
# Out:
#          Date   Sno     Time State/UnionTerritory ConfirmedIndianNational  \
# 0  2020-06-01  2534  8:00 AM              Haryana                       -
# 1  2020-06-02  2570  8:00 AM              Haryana                       -
# 2  2020-06-03  2606  8:00 AM              Haryana                       -
# 3  2020-06-04  2642  8:00 AM              Haryana                       -
# 4  2020-06-05  2678  8:00 AM              Haryana                       -
# 5  2020-06-06  2714  8:00 AM              Haryana                       -
# 6  2020-06-07  2750  8:00 AM              Haryana                       -
# 7  2020-06-08  2786  8:00 AM              Haryana                       -
# 8  2020-06-09  2822  8:00 AM              Haryana                       -
# 9  2020-06-10  2858  8:00 AM              Haryana                       -
# 10 2020-06-11  2895  8:00 AM              Haryana                       -
# 11 2020-06-12  2931  8:00 AM              Haryana                       -
# 12 2020-06-13  2967  8:00 AM              Haryana                       -
# 13 2020-06-14  3003  8:00 AM              Haryana                       -
# 14 2020-06-15  3039  8:00 AM              Haryana                       -
# 15 2020-06-16  3075  8:00 AM              Haryana                       -
# 16 2020-06-17  3111  8:00 AM              Haryana                       -
# 17 2020-06-18  3147  8:00 AM              Haryana                       -
# 18 2020-06-19  3183  8:00 AM              Haryana                       -
# 19 2020-06-20  3219  8:00 AM              Haryana                       -
# 20 2020-06-21  3255  8:00 AM              Haryana                       -
# 21 2020-06-22  3291  8:00 AM              Haryana                       -
# 22 2020-06-23  3327  8:00 AM              Haryana                       -
# 23 2020-06-24  3363  8:00 AM              Haryana                       -
# 24 2020-06-25  3399  8:00 AM              Haryana                       -
# 25 2020-06-26  3435  8:00 AM              Haryana                       -
# 26 2020-06-27  3471  8:00 AM              Haryana                       -
# 27 2020-06-28  3507  8:00 AM              Haryana                       -
# 28 2020-06-29  3543  8:00 AM              Haryana                       -
# 29 2020-06-30  3579  8:00 AM              Haryana                       -
#
#    ConfirmedForeignNational  Cured  Deaths  Confirmed
# 0                         -   1048      20       2091
# 1                         -   1055      21       2356
# 2                         -   1069      23       2652
# 3                         -   1089      23       2954
# 4                         -   2134      24       3281
# 5                         -   2134      24       3597
# 6                         -   2134      24       3952
# 7                         -   2134      28       4448
# 8                         -   2134      39       4854
# 9                         -   2134      45       5209
# 10                        -   2188      52       5579
# 11                        -   2260      64       5968
# 12                        -   2475      70       6334
# 13                        -   2803      78       6749
# 14                        -   3003      88       7208
# 15                        -   3565     100       7722
# 16                        -   3748     118       8272
# 17                        -   3952     130       8832
# 18                        -   4556     134       9218
# 19                        -   4889     144       9743
# 20                        -   5128     149      10223
# 21                        -   5557     160      10635
# 22                        -   5916     169      11025
# 23                        -   6498     178      11520
# 24                        -   6925     188      12010
# 25                        -   7380     198      12463
# 26                        -   8016     211      12884
# 27                        -   8472     218      13427
# 28                        -   8917     223      13829
# 29                        -   9502     232      14210

# %%
dateList = [i.strftime("%d") for i in df['Date'].tolist()]


plot.plot(dateList,df['Confirmed'].tolist(),'g', label='Confirmed In Haryana', linewidth =1)
plot.plot(dateList,df['Cured'].tolist(),'b', label='Cured In Haryana', linewidth =1)
plot.plot(dateList,df['Deaths'].tolist(),'r', label='Deaths In Haryana', linewidth =1)

plot.title('COVID-19 DATA ')
plot.xlabel('Days Of June')
plot.xticks(rotation=90)
plot.ylabel('Number Of People')
plot.legend()

plot.grid(True, color='K')
plot.legend(loc='best')
plot.savefig('Haryana1.jpg')
plot.show()
